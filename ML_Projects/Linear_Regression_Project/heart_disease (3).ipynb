# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart_disease_uci.csv')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  NaN
# 916  st-t abnormality     NaN    NaN      NaN          NaN  NaN
# 917  st-t abnormality   100.0  False      0.0          NaN  NaN
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  NaN
# 919    lv hypertrophy    93.0   True      0.0          NaN  NaN
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 915                NaN    1
# 916                NaN    0
# 917       fixed defect    2
# 918                NaN    0
# 919                NaN    1
#
# [920 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df = df.drop(['id','dataset','ca','thal'],axis=1)

# %%
df['num'] = df['num'].apply(lambda x: 1 if x > 0 else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   cp        920 non-null    object
#  3   trestbps  861 non-null    float64
#  4   chol      890 non-null    float64
#  5   fbs       830 non-null    object
#  6   restecg   918 non-null    object
#  7   thalch    865 non-null    float64
#  8   exang     865 non-null    object
#  9   oldpeak   858 non-null    float64
#  10  slope     611 non-null    object
#  11  num       920 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 86.4+ KB

# %%
sns.distplot(df['trestbps'])
# Out:
# <Axes: xlabel='trestbps', ylabel='Density'>

# %%
outliner_index= df[df['trestbps'] == 0].index

# %%
df.drop(outliner_index,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       919 non-null    int64
#  1   sex       919 non-null    object
#  2   cp        919 non-null    object
#  3   trestbps  860 non-null    float64
#  4   chol      889 non-null    float64
#  5   fbs       829 non-null    object
#  6   restecg   917 non-null    object
#  7   thalch    864 non-null    float64
#  8   exang     864 non-null    object
#  9   oldpeak   857 non-null    float64
#  10  slope     610 non-null    object
#  11  num       919 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 93.3+ KB

# %%
df['trestbps'].fillna(df['trestbps'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       919 non-null    int64
#  1   sex       919 non-null    object
#  2   cp        919 non-null    object
#  3   trestbps  919 non-null    float64
#  4   chol      889 non-null    float64
#  5   fbs       829 non-null    object
#  6   restecg   917 non-null    object
#  7   thalch    864 non-null    float64
#  8   exang     864 non-null    object
#  9   oldpeak   857 non-null    float64
#  10  slope     610 non-null    object
#  11  num       919 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 93.3+ KB

# %%
sns.distplot(df['chol'])
# Out:
# <Axes: xlabel='chol', ylabel='Density'>

# %%
df[df['chol'] == 0].index
# Out:
# Index([597, 598, 599, 600, 601, 602, 603, 604, 605, 606,
#        ...
#        785, 787, 788, 796, 812, 818, 819, 822, 839, 840],
#       dtype='int64', length=171)

# %%
df['chol']= df['chol'].replace(0,np.nan)
df['chol'].fillna(df['chol'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       919 non-null    int64
#  1   sex       919 non-null    object
#  2   cp        919 non-null    object
#  3   trestbps  919 non-null    float64
#  4   chol      919 non-null    float64
#  5   fbs       829 non-null    object
#  6   restecg   917 non-null    object
#  7   thalch    864 non-null    float64
#  8   exang     864 non-null    object
#  9   oldpeak   857 non-null    float64
#  10  slope     610 non-null    object
#  11  num       919 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 93.3+ KB

# %%
sns.distplot(df['thalch'])
# Out:
# <Axes: xlabel='thalch', ylabel='Density'>

# %%
df['thalch'].isnull().sum()
# Out:
# np.int64(55)

# %%
df['thalch'] = df['thalch'].fillna(df['thalch'].mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       919 non-null    int64
#  1   sex       919 non-null    object
#  2   cp        919 non-null    object
#  3   trestbps  919 non-null    float64
#  4   chol      919 non-null    float64
#  5   fbs       829 non-null    object
#  6   restecg   917 non-null    object
#  7   thalch    919 non-null    object
#  8   exang     864 non-null    object
#  9   oldpeak   857 non-null    float64
#  10  slope     610 non-null    object
#  11  num       919 non-null    int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 93.3+ KB

# %%
df['oldpeak'].isnull().sum()
# Out:
# np.int64(62)

# %%
sns.distplot(df['oldpeak'])
# Out:
# <Axes: xlabel='oldpeak', ylabel='Density'>

# %%
(df['oldpeak'] < 0).sum()
# Out:
# np.int64(12)

# %%
df[df['oldpeak'] < 0]['oldpeak'].describe()
# Out:
# count    12.000000
# mean     -1.058333
# std       0.689477
# min      -2.600000
# 25%      -1.200000
# 50%      -0.950000
# 75%      -0.650000
# max      -0.100000
# Name: oldpeak, dtype: float64

# %%
outlier_index = df[df['oldpeak'] < 0].index
df.drop(outlier_index, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       827 non-null    object
#  6   restecg   905 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     852 non-null    object
#  9   oldpeak   845 non-null    float64
#  10  slope     598 non-null    object
#  11  num       907 non-null    int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 92.1+ KB

# %%
df['oldpeak'].isnull().sum()
# Out:
# np.int64(62)

# %%
df['oldpeak'].fillna(df['oldpeak'].median(),inplace=True)

# %%
df['oldpeak'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       827 non-null    object
#  6   restecg   905 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     852 non-null    object
#  9   oldpeak   907 non-null    float64
#  10  slope     598 non-null    object
#  11  num       907 non-null    int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 92.1+ KB

# %%
df
# Out:
#      age     sex               cp    trestbps   chol    fbs           restecg  \
# 0     63    Male   typical angina  145.000000  233.0   True    lv hypertrophy
# 1     67    Male     asymptomatic  160.000000  286.0  False    lv hypertrophy
# 2     67    Male     asymptomatic  120.000000  229.0  False    lv hypertrophy
# 3     37    Male      non-anginal  130.000000  250.0  False            normal
# 4     41  Female  atypical angina  130.000000  204.0  False    lv hypertrophy
# ..   ...     ...              ...         ...    ...    ...               ...
# 915   54  Female     asymptomatic  127.000000  333.0   True  st-t abnormality
# 916   62    Male   typical angina  132.286047  139.0  False  st-t abnormality
# 917   55    Male     asymptomatic  122.000000  223.0   True  st-t abnormality
# 918   58    Male     asymptomatic  132.286047  385.0   True    lv hypertrophy
# 919   62    Male  atypical angina  120.000000  254.0  False    lv hypertrophy
#
#                                                 thalch  exang  oldpeak  \
# 0                                                150.0  False      2.3
# 1                                                108.0   True      1.5
# 2                                                129.0   True      2.6
# 3                                                187.0  False      3.5
# 4                                                172.0  False      1.4
# ..                                                 ...    ...      ...
# 915                                              154.0  False      0.0
# 916  <bound method Series.mean of 0      150.0\n1  ...    NaN      0.5
# 917                                              100.0  False      0.0
# 918  <bound method Series.mean of 0      150.0\n1  ...    NaN      0.5
# 919                                               93.0   True      0.0
#
#            slope  num
# 0    downsloping    0
# 1           flat    1
# 2           flat    1
# 3    downsloping    0
# 4      upsloping    0
# ..           ...  ...
# 915          NaN    1
# 916          NaN    0
# 917          NaN    1
# 918          NaN    0
# 919          NaN    1
#
# [907 rows x 12 columns]

# %%
sns.countplot(x= df['fbs'])
# Out:
# <Axes: xlabel='fbs', ylabel='count'>

# %%
df['fbs'].isnull().sum()
# Out:
# np.int64(80)

# %%
df['fbs'].value_counts()
# Out:
# fbs
# False    689
# True     138
# Name: count, dtype: int64

# %%
df['fbs']= df['fbs'].fillna(df['fbs'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       907 non-null    bool
#  6   restecg   905 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     852 non-null    object
#  9   oldpeak   907 non-null    float64
#  10  slope     598 non-null    object
#  11  num       907 non-null    int64
# dtypes: bool(1), float64(3), int64(2), object(6)
# memory usage: 85.9+ KB

# %%
df['restecg'].value_counts()
# Out:
# restecg
# normal              543
# lv hypertrophy      187
# st-t abnormality    175
# Name: count, dtype: int64

# %%
df['restecg'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['restecg'] = df['restecg'].fillna(df['restecg'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       907 non-null    bool
#  6   restecg   907 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     852 non-null    object
#  9   oldpeak   907 non-null    float64
#  10  slope     598 non-null    object
#  11  num       907 non-null    int64
# dtypes: bool(1), float64(3), int64(2), object(6)
# memory usage: 85.9+ KB

# %%
df['exang'].value_counts()
# Out:
# exang
# False    518
# True     334
# Name: count, dtype: int64

# %%
df['exang'].isnull().sum()
# Out:
# np.int64(55)

# %%
df['exang'] = df['exang'].fillna(df['exang'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       907 non-null    bool
#  6   restecg   907 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     907 non-null    bool
#  9   oldpeak   907 non-null    float64
#  10  slope     598 non-null    object
#  11  num       907 non-null    int64
# dtypes: bool(2), float64(3), int64(2), object(5)
# memory usage: 79.7+ KB

# %%
df['slope'].value_counts()
# Out:
# slope
# flat           339
# upsloping      198
# downsloping     61
# Name: count, dtype: int64

# %%
df['slope'].isnull().sum()
# Out:
# np.int64(309)

# %%
df= df.drop(['slope'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       907 non-null    bool
#  6   restecg   907 non-null    object
#  7   thalch    907 non-null    object
#  8   exang     907 non-null    bool
#  9   oldpeak   907 non-null    float64
#  10  num       907 non-null    int64
# dtypes: bool(2), float64(3), int64(2), object(4)
# memory usage: 72.6+ KB

# %%
df.head()
# Out:
#    age     sex               cp  trestbps   chol    fbs         restecg  \
# 0   63    Male   typical angina     145.0  233.0   True  lv hypertrophy
# 1   67    Male     asymptomatic     160.0  286.0  False  lv hypertrophy
# 2   67    Male     asymptomatic     120.0  229.0  False  lv hypertrophy
# 3   37    Male      non-anginal     130.0  250.0  False          normal
# 4   41  Female  atypical angina     130.0  204.0  False  lv hypertrophy
#
#   thalch  exang  oldpeak  num
# 0  150.0  False      2.3    0
# 1  108.0   True      1.5    1
# 2  129.0   True      2.6    1
# 3  187.0  False      3.5    0
# 4  172.0  False      1.4    0

# %%
df['thalch'].unique()
# Out:
# array([150.0, 108.0, 129.0, 187.0, 172.0, 178.0, 160.0, 163.0, 147.0,
#        155.0, 148.0, 153.0, 142.0, 173.0, 162.0, 174.0, 168.0, 139.0,
#        171.0, 144.0, 132.0, 158.0, 114.0, 151.0, 161.0, 179.0, 120.0,
#        112.0, 137.0, 157.0, 169.0, 165.0, 123.0, 128.0, 152.0, 140.0,
#        188.0, 109.0, 125.0, 131.0, 170.0, 113.0, 99.0, 177.0, 141.0,
#        180.0, 111.0, 143.0, 182.0, 156.0, 115.0, 149.0, 145.0, 146.0,
#        175.0, 186.0, 185.0, 159.0, 130.0, 190.0, 136.0, 97.0, 127.0,
#        154.0, 133.0, 126.0, 202.0, 103.0, 166.0, 164.0, 184.0, 124.0,
#        122.0, 96.0, 138.0, 88.0, 105.0, 194.0, 195.0, 106.0, 167.0, 95.0,
#        192.0, 117.0, 121.0, 116.0, 71.0, 118.0, 181.0, 134.0, 90.0, 98.0,
#        176.0, 135.0, 110.0, <bound method Series.mean of 0      150.0
#                             1      108.0
#                             2      129.0
#                             3      187.0
#                             4      172.0
#                                    ...
#                             915    154.0
#                             916      NaN
#                             917    100.0
#                             918      NaN
#                             919     93.0
#                             Name: thalch, Length: 919, dtype: float64>,
#        100.0, 87.0, 102.0, 92.0, 91.0, 82.0, 119.0, 94.0, 104.0, 60.0,
#        83.0, 63.0, 70.0, 77.0, 72.0, 78.0, 86.0, 93.0, 67.0, 84.0, 80.0,
#        107.0, 69.0, 73.0], dtype=object)

# %%
df['thalch']= pd.to_numeric(df['thalch'], errors= 'coerce')

# %%
df['thalch']=df['thalch'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       907 non-null    int64
#  1   sex       907 non-null    object
#  2   cp        907 non-null    object
#  3   trestbps  907 non-null    float64
#  4   chol      907 non-null    float64
#  5   fbs       907 non-null    bool
#  6   restecg   907 non-null    object
#  7   thalch    852 non-null    float64
#  8   exang     907 non-null    bool
#  9   oldpeak   907 non-null    float64
#  10  num       907 non-null    int64
# dtypes: bool(2), float64(4), int64(2), object(3)
# memory usage: 72.6+ KB

# %%
df['thalch'].isnull().sum()
# Out:
# np.int64(55)

# %%
sns.distplot(df['thalch'])
# Out:
# <Axes: xlabel='thalch', ylabel='Density'>

# %%
df['thalch'].fillna(df['thalch'].mean(),inplace=True)

# %%
df['thalch'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    age     sex               cp  trestbps   chol    fbs         restecg  \
# 0   63    Male   typical angina     145.0  233.0   True  lv hypertrophy
# 1   67    Male     asymptomatic     160.0  286.0  False  lv hypertrophy
# 2   67    Male     asymptomatic     120.0  229.0  False  lv hypertrophy
# 3   37    Male      non-anginal     130.0  250.0  False          normal
# 4   41  Female  atypical angina     130.0  204.0  False  lv hypertrophy
#
#    thalch  exang  oldpeak  num
# 0   150.0  False      2.3    0
# 1   108.0   True      1.5    1
# 2   129.0   True      2.6    1
# 3   187.0  False      3.5    0
# 4   172.0  False      1.4    0

# %%
df['cp'].value_counts()
# Out:
# cp
# asymptomatic       489
# non-anginal        199
# atypical angina    174
# typical angina      45
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
df_encoded = pd.get_dummies(df, columns=['cp', 'restecg'])
le = LabelEncoder()
df_encoded['sex'] = le.fit_transform(df_encoded['sex'])
df_encoded = df_encoded.astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_encoded['sex'] = le.fit_transform(df_encoded['sex'])

# %%
df_encoded= df_encoded.astype(int)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       907 non-null    int64
#  1   sex                       907 non-null    int64
#  2   trestbps                  907 non-null    int64
#  3   chol                      907 non-null    int64
#  4   fbs                       907 non-null    int64
#  5   thalch                    907 non-null    int64
#  6   exang                     907 non-null    int64
#  7   oldpeak                   907 non-null    int64
#  8   num                       907 non-null    int64
#  9   cp_asymptomatic           907 non-null    int64
#  10  cp_atypical angina        907 non-null    int64
#  11  cp_non-anginal            907 non-null    int64
#  12  cp_typical angina         907 non-null    int64
#  13  restecg_lv hypertrophy    907 non-null    int64
#  14  restecg_normal            907 non-null    int64
#  15  restecg_st-t abnormality  907 non-null    int64
# dtypes: int64(16)
# memory usage: 120.5 KB

# %%
X = df_encoded.drop('num', axis=1)
y = df_encoded['num']
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
model_LR = LogisticRegression()
model_LR.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_LR = model_LR.predict(X_test_scaled)
accuracy_score(y_test, y_pred_LR)
# Out:
# 0.8021978021978022

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = model_knn.predict(X_test_scaled)

# %%
accuracy_score(y_pred_knn,y_test)
# Out:
# 0.7967032967032966

# %%
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[60, 16],
#        [21, 85]])

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        76
#            1       0.84      0.80      0.82       106
#
#     accuracy                           0.80       182
#    macro avg       0.79      0.80      0.79       182
# weighted avg       0.80      0.80      0.80       182

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_NB = GaussianNB()
model_NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_NB = model_NB.predict(X_test)

# %%
accuracy_score(y_pred_NB,y_test)
# Out:
# 0.7912087912087912

# %%
confusion_matrix(y_pred_NB,y_test)
# Out:
# array([[59, 21],
#        [17, 85]])

# %%
print(classification_report(y_pred_NB,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76        80
#            1       0.80      0.83      0.82       102
#
#     accuracy                           0.79       182
#    macro avg       0.79      0.79      0.79       182
# weighted avg       0.79      0.79      0.79       182

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_DT = DecisionTreeClassifier(random_state=42)
model_DT.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_DT = model_DT.predict(X_test_scaled)

# %%
accuracy_score(y_pred_DT,y_test)
# Out:
# 0.7142857142857143

# %%
print(classification_report(y_test,y_pred_DT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68        76
#            1       0.78      0.71      0.74       106
#
#     accuracy                           0.71       182
#    macro avg       0.71      0.72      0.71       182
# weighted avg       0.72      0.71      0.72       182

# %%
confusion_matrix(y_pred_DT,y_test)
# Out:
# array([[55, 31],
#        [21, 75]])

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(kernel='rbf',probability = True)
model_svm.fit(X_train_scaled,y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_svm = model_svm.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred_svm)
# Out:
# 0.8296703296703297

# %%
confusion_matrix(y_test,y_pred_svm)
# Out:
# array([[57, 19],
#        [12, 94]])

# %%
print(classification_report(y_test,y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79        76
#            1       0.83      0.89      0.86       106
#
#     accuracy                           0.83       182
#    macro avg       0.83      0.82      0.82       182
# weighted avg       0.83      0.83      0.83       182

# %%
import pickle

with open('model_svm.pkl', 'wb') as f:
    pickle.dump(model_svm, f)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

with open('columns.pkl', 'wb') as f:
    pickle.dump(list(X.columns), f)

print("Saved: model_svm.pkl, scaler.pkl, columns.pkl")
# Out:
# Saved: model_svm.pkl, scaler.pkl, columns.pkl
